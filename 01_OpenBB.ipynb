# %%
from openbb import obb
obb.user.preferences.output_type = "dataframe"

# %% [markdown]
# ## Historical price data

# %%
data = obb.equity.price.historical("SPY", provider="yfinance")

# %%
print(data)
# Out:
#                   open        high         low       close    volume  dividend
# date
# 2024-01-08  468.429993  474.750000  468.299988  474.600006  74879100       0.0
# 2024-01-09  471.869995  474.929993  471.350006  473.880005  65931400       0.0
# 2024-01-10  474.160004  477.450012  473.869995  476.559998  67310600       0.0
# 2024-01-11  477.589996  478.119995  472.260010  476.350006  77940700       0.0
# 2024-01-12  477.839996  478.600006  475.230011  476.679993  57944000       0.0
# ...                ...         ...         ...         ...       ...       ...
# 2024-12-31  589.909973  590.640015  584.419983  586.080017  57052700       0.0
# 2025-01-02  589.390015  591.130005  580.500000  584.640015  50204000       0.0
# 2025-01-03  587.530029  592.599976  586.429993  591.950012  37888500       0.0
# 2025-01-06  596.270020  599.700012  593.599976  595.359985  47679400       0.0
# 2025-01-07  597.419983  597.750000  586.780029  588.630005  60256400       0.0
#
# [252 rows x 6 columns]

# %% [markdown]
# ## Fundamental data

# %%
obb.equity.fundamental.metrics("AAPL,MSFT,NVDA", provider="yfinance").T
# Out:
#                                          0                1                2
# symbol                                AAPL             MSFT             NVDA
# market_cap                 3661198000128.0  3140270161920.0  3432028569600.0
# pe_ratio                         39.837173         34.84901         55.17323
# forward_pe                       29.120844        28.136654        31.628029
# peg_ratio_ttm                       2.2072           2.2172           1.0044
# enterprise_to_ebitda                27.588           23.132           58.085
# earnings_growth                     -0.341            0.104             1.68
# earnings_growth_quarterly           -0.358            0.107            1.682
# revenue_per_share                   25.485           34.202             3.91
# revenue_growth                       0.061             0.16            1.224
# enterprise_to_revenue                9.501           12.426           36.902
# quick_ratio                          0.745            1.163            3.503
# current_ratio                        0.867            1.301            4.269
# debt_to_equity                     209.059           33.657           17.221
# gross_margin                       0.46206          0.69349          0.75976
# operating_margin                   0.31171          0.46584          0.62057
# ebitda_margin                      0.34437           0.5372           0.6353
# profit_margin                      0.23971          0.35608          0.55041
# return_on_assets                   0.21464          0.14592          0.55258
# return_on_equity                   1.57413          0.35604          1.23767
# dividend_yield                      0.0041           0.0079           0.0003
# dividend_yield_5y_avg               0.0061           0.0086           0.0009
# payout_ratio                        0.1612           0.2477           0.0111
# book_value                           3.767           38.693            1.744
# price_to_book                     64.29785        10.915928         80.35551
# enterprise_value             3715091398656    3158679486464    3553896693760
# overall_risk                           1.0              3.0              8.0
# audit_risk                             3.0              9.0              7.0
# board_risk                             1.0              5.0             10.0
# compensation_risk                      3.0              3.0              5.0
# shareholder_rights_risk                1.0              2.0              6.0
# beta                                  1.24            0.904            1.657
# price_return_1y                   0.300875         0.103456         1.578473
# currency                               USD              USD              USD

# %% [markdown]
# ## Stock screeners

# %% [markdown]
# ### #1 Overview screener

# %%
obb.equity.compare.groups(group="industry", metric="valuation", provider="finviz")
# Out:
#                              name    market_cap  performance_1d  forward_pe  \
# 0        Pharmaceutical Retailers    8780000000          0.0193        7.14
# 1                 REIT - Mortgage   56480000000         -0.0071        7.18
# 2                 Marine Shipping   32650000000          0.0063        7.31
# 3         Insurance - Reinsurance   48820000000          0.0198        7.32
# 4                     Coking Coal    9200000000         -0.0058        7.89
# ..                            ...           ...             ...         ...
# 140  REIT - Healthcare Facilities  155670000000         -0.0001       56.81
# 141                 REIT - Office   88860000000         -0.0184       66.59
# 142     Infrastructure Operations   34230000000         -0.0035      159.60
# 143               Shell Companies   29060000000         -0.0028      162.48
# 144     Real Estate - Diversified    6550000000         -0.0102         NaN
#
#      eps_growth_past_5y  eps_growth_next_5y    volume  price_to_sales  \
# 0               -0.0598             -0.0002  21370000            0.06
# 1               -0.2211              0.0150  55820000            1.88
# 2                0.2198              0.1800  21340000            1.00
# 3                0.5391              0.1357   2590000            0.87
# 4                0.0614              0.0800   4170000            0.90
# ..                  ...                 ...       ...             ...
# 140             -0.1270              0.1216  31110000            6.65
# 141             -0.2074              0.0061  26270000            4.52
# 142                 NaN              0.1267    840170            3.27
# 143                 NaN                 NaN  10760000           15.36
# 144              0.1840              0.2000    496500            4.02
#
#      price_to_book  price_to_cash  price_to_free_cash_flow  \
# 0             0.81           2.71                   461.49
# 1             0.83           3.81                    13.14
# 2             0.89           4.51                     5.78
# 3             1.17            NaN                     2.56
# 4             1.50           6.04                     9.89
# ..             ...            ...                      ...
# 140           1.99          22.81                    26.91
# 141           1.31           9.95                    16.04
# 142           7.29           8.25                    32.03
# 143           2.68          37.90                   197.58
# 144           1.84           6.27                    30.23
#
#      sales_growth_past_5_years     pe     peg
# 0                       0.0489    NaN     NaN
# 1                       0.3119  14.06    9.36
# 2                       0.2368   4.71    0.26
# 3                       0.1632   6.33    0.47
# 4                       0.1990   9.01    1.13
# ..                         ...    ...     ...
# 140                     0.1418  91.81    7.55
# 141                     0.0517  71.43  116.79
# 142                     0.0932  37.18    2.93
# 143                     0.7588  78.12     NaN
# 144                     0.1839  43.14    2.16
#
# [145 rows x 14 columns]

# %% [markdown]
# ### #2 Top gainers

# %%
obb.equity.compare.groups(group="technology", metric="performance", provider="finviz")
# Out:
#                                    name  performance_1d  performance_1w  \
# 0                  Consumer Electronics         -0.0110         -0.0387
# 1             Software - Infrastructure         -0.0175         -0.0110
# 2                Software - Application         -0.0206         -0.0048
# 3               Communication Equipment         -0.0027          0.0052
# 4       Information Technology Services          0.0038          0.0092
# 5    Scientific & Technical Instruments          0.0002          0.0161
# 6                        Semiconductors         -0.0431          0.0233
# 7                 Electronic Components         -0.0004          0.0253
# 8   Electronics & Computer Distribution          0.0216          0.0308
# 9                     Computer Hardware         -0.0243          0.0431
# 10  Semiconductor Equipment & Materials         -0.0070          0.0838
# 11                                Solar          0.0409          0.1163
#
#     performance_1m  performance_3m  performance_6m  performance_1y  \
# 0          -0.0032          0.0924          0.0590          0.3268
# 1          -0.0634          0.0480         -0.0167          0.1908
# 2          -0.0660          0.1449          0.2324          0.2806
# 3          -0.0157          0.1002          0.2700          0.3059
# 4          -0.0253          0.0075          0.1855          0.2089
# 5          -0.0413          0.0746          0.1382          0.2587
# 6           0.0264          0.0964          0.0446          0.9532
# 7          -0.0184          0.1081          0.0806          0.3719
# 8          -0.0253         -0.0839          0.0143          0.0706
# 9           0.0178          0.0874         -0.0193          0.5732
# 10          0.0586         -0.0740         -0.2717          0.1209
# 11          0.0628         -0.1556         -0.1579         -0.3133
#
#     performance_ytd  analyst_recommendation     volume  volume_average  \
# 0           -0.0320                    1.98  728470000       105450000
# 1           -0.0036                    1.56  577800000       381520000
# 2            0.0036                    1.83  675210000       476720000
# 3            0.0063                    2.20  122230000       126680000
# 4            0.0114                    2.17  226560000       140550000
# 5            0.0181                    2.16   52300000        35480000
# 6            0.0416                    1.49  715860000       559310000
# 7            0.0264                    1.96   72990000        82250000
# 8            0.0235                    2.41    2380000         2500000
# 9            0.0529                    1.91  306180000       354980000
# 10           0.0882                    1.72   42850000        43090000
# 11           0.1312                    1.89  198750000        67500000
#
#     volume_relative
# 0              6.91
# 1              1.51
# 2              1.42
# 3              0.96
# 4              1.61
# 5              1.47
# 6              1.28
# 7              0.89
# 8              0.95
# 9              0.86
# 10             0.99
# 11             2.94

# %% [markdown]
# ### #3 Overview grouped by sector

# %%
obb.equity.compare.groups(group="sector", metric="overview", provider="finviz")
# Out:
#                       name      market_cap  performance_1d  dividend_yield  \
# 0               Technology  21954010000000         -0.0232          0.0063
# 1        Consumer Cyclical   8584760000000         -0.0173          0.0079
# 2   Communication Services   9061710000000         -0.0097          0.0065
# 3              Real Estate   1561150000000         -0.0090          0.0397
# 4                Financial  12034130000000         -0.0030          0.0190
# 5              Industrials   5692340000000         -0.0028          0.0133
# 6       Consumer Defensive   3974860000000         -0.0025          0.0243
# 7                Utilities   1585030000000         -0.0023          0.0295
# 8          Basic Materials   1875170000000         -0.0004          0.0245
# 9               Healthcare   7667880000000          0.0049          0.0159
# 10                  Energy   3507670000000          0.0111          0.0452
#
#        pe  forward_pe   peg  float_short      volume Stocks
# 0   43.04       27.13  2.33       0.0272  3720000000    781
# 1   27.09       22.24  2.27       0.0455  2680000000    566
# 2   40.23       29.32  2.49       0.0242  1120000000    261
# 3   36.11       30.22  5.16       0.0453   345850000    267
# 4   18.02       15.92  1.53       0.0135  1030000000    908
# 5   24.90       20.77  2.04       0.0397  3540000000    664
# 6   25.36       19.61  3.12       0.0177   390520000    247
# 7   20.16       17.15  2.23       0.0215   190590000    111
# 8   20.47       13.96  2.13       0.0212   666720000    269
# 9   34.18       17.93  2.57       0.0446  3380000000   1171
# 10  12.89       11.86  1.98       0.0282   658010000    253

# %% [markdown]
# ## Historical futures prices

# %%
import pandas as pd
from openbb import obb
obb.user.preferences.output_type = "dataframe"

# %%
data = obb.derivatives.futures.curve(symbol="VX")

# %%
print(data)
# Out:
#   expiration  price
# 0    2025-01  17.85
# 1    2025-02  18.20
# 2    2025-03  18.45
# 3    2025-04  18.55
# 4    2025-05  18.65
# 5    2025-06  18.70
# 6    2025-07  19.00
# 7    2025-08  19.00
# 8    2025-09  19.20

# %%
data.index = pd.to_datetime(data.expiration)
data.plot()
# Out:
# <Axes: xlabel='expiration'>

# %% [markdown]
# ## Historical data for individual expiration

# %%
expirations = [
    "2025-12",
    "2026-12",
    "2027-12",
    "2028-12",
    "2029-12",
    "2030-12",
]

# %%
contracts = []
for expiration in expirations:
    df = (
        obb
        .derivatives
        .futures
        .historical(
            symbol="CL",
            expiration=expiration,
            start_date="2020-01-01",
            end_date="2022-12-31"
        )
    ).rename(columns={
        "close": expiration
    })
    contracts.append(df[expiration])

# %%
historical = (
    pd
    .DataFrame(contracts)
    .transpose()
    .dropna()
)

# %%
print(historical)
# Out:
#               2025-12    2026-12    2027-12    2028-12    2029-12    2030-12
# date
# 2020-01-02  52.750000  53.130001  53.180000  53.180000  53.180000  53.180000
# 2020-01-03  52.419998  52.910000  52.959999  52.959999  52.959999  52.959999
# 2020-01-06  52.349998  52.840000  52.889999  52.889999  52.889999  52.889999
# 2020-01-07  52.669998  53.169998  53.240002  53.240002  53.240002  53.240002
# 2020-01-08  52.270000  52.770000  52.840000  52.840000  52.840000  52.840000
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-23  67.779999  64.669998  62.119999  59.990002  58.139999  56.389999
# 2022-12-27  67.860001  64.730003  62.180000  60.049999  58.200001  56.450001
# 2022-12-28  68.290001  65.339996  62.790001  60.650002  58.790001  57.040001
# 2022-12-29  67.500000  64.599998  62.119999  59.980000  58.119999  56.369999
# 2022-12-30  68.629997  65.620003  63.110001  60.919998  58.970001  57.220001
#
# [756 rows x 6 columns]

# %%
historical.iloc[-1].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Options Contracts

# %%
from openbb import obb
obb.user.preferences.output_type = "dataframe"

# %%
chains = obb.derivatives.options.chains(symbol="SPY")

# %%
chains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9950 entries, 0 to 9949
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   underlying_symbol   9950 non-null   object
#  1   underlying_price    9950 non-null   float64
#  2   contract_symbol     9950 non-null   object
#  3   expiration          9950 non-null   object
#  4   dte                 9950 non-null   int64
#  5   strike              9950 non-null   float64
#  6   option_type         9950 non-null   object
#  7   open_interest       9950 non-null   int64
#  8   volume              9950 non-null   int64
#  9   theoretical_price   9950 non-null   float64
#  10  last_trade_price    9950 non-null   float64
#  11  last_trade_time     8180 non-null   datetime64[ns]
#  12  tick                9950 non-null   object
#  13  bid                 9950 non-null   float64
#  14  bid_size            9950 non-null   int64
#  15  ask                 9950 non-null   float64
#  16  ask_size            9950 non-null   int64
#  17  open                9950 non-null   float64
#  18  high                9950 non-null   float64
#  19  low                 9950 non-null   float64
#  20  prev_close          9950 non-null   float64
#  21  change              9950 non-null   float64
#  22  change_percent      9950 non-null   float64
#  23  implied_volatility  9950 non-null   float64
#  24  delta               9950 non-null   float64
#  25  gamma               9950 non-null   float64
#  26  theta               9950 non-null   float64
#  27  vega                9950 non-null   float64
#  28  rho                 9950 non-null   float64
# dtypes: datetime64[ns](1), float64(18), int64(5), object(5)
# memory usage: 2.2+ MB

# %%
obb.equity.price.historical(
    symbol="SPY250321C00550000",
    provider="yfinance",
)[["close", "volume"]]
# Out:
#                 close  volume
# date
# 2024-01-08   7.580000       2
# 2024-01-10   8.480000       3
# 2024-01-17   7.610000      15
# 2024-01-22  10.310000       0
# 2024-01-23  10.260000      36
# ...               ...     ...
# 2024-12-31  46.340000      87
# 2025-01-02  45.630001     178
# 2025-01-03  51.509998     123
# 2025-01-06  54.310001      34
# 2025-01-07  48.720001      53
#
# [240 rows x 2 columns]

# %% [markdown]
# ## Historical factor data

# %%
import pandas_datareader as pdr

# %%
factors = pdr.get_data_famafrench("F-F_Research_Data_Factors")
# Out:
# C:\Users\Kokso\AppData\Local\Temp\ipykernel_9316\2643818942.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   factors = pdr.get_data_famafrench("F-F_Research_Data_Factors")
# C:\Users\Kokso\AppData\Local\Temp\ipykernel_9316\2643818942.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   factors = pdr.get_data_famafrench("F-F_Research_Data_Factors")

# %%
print(factors["DESCR"])
# Out:
# F-F Research Data Factors
# -------------------------
#
# This file was created by CMPT_ME_BEME_RETS using the 202411 CRSP database. The 1-month TBill rate data until 202405 are from Ibbotson Associates. Starting from 202406, the 1-month TBill rate is from ICE BofA US 1-Month Treasury Bill Index. Copyright 2024 Eugene F. Fama and Kenneth R. French
#
#   0 : (59 rows x 4 cols)
#   1 : Annual Factors: January-December (4 rows x 4 cols)

# %%
print(factors[0].head())
# Out:
#          Mkt-RF   SMB    HML    RF
# Date
# 2020-01   -0.11 -3.13  -6.25  0.13
# 2020-02   -8.13  1.07  -3.80  0.12
# 2020-03  -13.39 -4.79 -13.88  0.13
# 2020-04   13.65  2.45  -1.34  0.00
# 2020-05    5.58  2.49  -4.85  0.01

# %%
print(factors[1].head())
# Out:
#       Mkt-RF    SMB    HML    RF
# Date
# 2020   23.66  12.72 -46.10  0.45
# 2021   23.57  -3.78  25.39  0.04
# 2022  -21.58  -7.04  25.97  1.43
# 2023   21.69  -3.28 -13.70  4.95
